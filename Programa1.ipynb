# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidGGs5/Fundamentos/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
X = "Carlos"
variableBoleana = True

print("Hola", x, X, "X")
# Out:
# Hola 5 Carlos X

# %%
base = int(input("Ingresa la base: "))
altura = int(input("Ingresa la altura: "))
area = base * altura / 2
print("El area del triangulo es: ", float(area))
# Out:
# Ingresa la base: 5
# Ingresa la altura: 3
# El area del triangulo es:  7.5

# %%
z = 10
a = "hola"
print (z * a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
numero1 = float(input("ingresar el primer numero: "))
numero2 = float(input("ingresar el segundo numero: "))
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
elif numero1 == numero2:
  print("Los numeros", numero1, "y", numero2, "son iguales")
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# ingresar el primer numero: 2
# ingresar el segundo numero: 2
# Los numeros 2.0 y 2.0 son iguales

# %%
10 > 5
# Out:
# False

# %%
5 > 10
# Out:
# False

# %%
10 > 5 and 5 < 10
# Out:
# True

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
10 > 5 or 5 > 10
# Out:
# True

# %%
edad = int(input("Dame tu edad: "))
if edad <= 10:
  print("Eres un niño")
elif edad <= 18:
  print("Eres un adolescente")
elif edad <= 30:
  print("Eres un adulto joven")
elif edad <= 65:
  print("Eres un adulto")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad: 45
# Eres un adulto

# %%
edad = int(input("Dame tu edad: "))
if edad >= 66 and edad <= 105:
  print("Eres un adulto mayor")
elif edad >= 31 and edad <= 65:
  print("Eres un adulto")
elif edad >= 19 and edad <= 30:
  print("Eres un adulto joven")
elif edad >= 11 and edad <=18:
  print("Eres un adolescente")
elif edad >= 0 and edad <=10:
  print("Eres un niño")
else:
  print("Error, edad no valida")
# Out:
# Dame tu edad: 56
# Eres un adulto

# %%
tabla = int(input("Ingresa la tabla: "))
x = int(input("Desde que numero debe empezar: "))
y = int(input("Hasta que numero debe llegar: "))
z = int(input("De cuanto en cuanto: "))
if tabla >= 0 and tabla <= 100:
        if x >= 0 and x <= 100:
          if y >= 0 and y <= 100:
            if z >= 0 and z <= 100:
              for i in range(x, y, z):
                print(tabla, "*", i, "=", tabla * i)
            else:
              print("Error, el tercer numero debe estar entre 0 y 100")
          else:
            print("Error, el segundo numero debe estar entre 0 y 100")
        else:
          print("Error, el primer numero debe estar entre 0 y 100")
# Out:
# Ingresa la tabla: 7
# Desde que numero debe empezar: 1
# Hasta que numero debe llegar: 105
# De cuanto en cuanto: 12
# Error, el segundo numero debe estar entre 0 y 100
