# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidGGs5/Fundamentos/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # **Ingenieria en Inteligencia Artifical**
#
#  # **Fundamentos de Programacion**
#
#  ## **Unidad 1**
#  ### Practica 1: Introducción al Lenguaje de programación Python
#
#  Docente: **Jose Gabriel Rodriguez Rivas**
#
#  Alumno: **David Leonardo Gómez Gaucín**
#
#  Numero de control: **26041637**

# %%
x = 5
X = "Hola mundo"
variableBoleana = True

print("Hola", x, X, "X")
# Out:
# Hola 5 Hola mundo X

# %%
base = int(input("Ingresa la base: "))
altura = int(input("Ingresa la altura: "))
area = base * altura / 2
print("El area del triangulo es: ", float(area))
# Out:
# Ingresa la base: 5
# Ingresa la altura: 3
# El area del triangulo es:  7.5

# %%
z = 10
a = "hola"
print (z * a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
numero1 = float(input("ingresar el primer numero: "))
numero2 = float(input("ingresar el segundo numero: "))
if numero1 > numero2:
  print("El numero", numero1, "es mayor que", numero2)
elif numero1 == numero2:
  print("Los numeros", numero1, "y", numero2, "son iguales")
else:
  print("El numero", numero2, "es mayor que", numero1)
# Out:
# ingresar el primer numero: 2
# ingresar el segundo numero: 2
# Los numeros 2.0 y 2.0 son iguales

# %%
10 > 5
# Out:
# False

# %%
5 > 10
# Out:
# False

# %%
10 > 5 and 5 < 10
# Out:
# True

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
10 > 5 or 5 > 10
# Out:
# True

# %%
edad = int(input("Dame tu edad: "))
if edad <= 10:
  print("Eres un niño")
elif edad <= 18:
  print("Eres un adolescente")
elif edad <= 30:
  print("Eres un adulto joven")
elif edad <= 65:
  print("Eres un adulto")
else:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad: 45
# Eres un adulto

# %%
edad = int(input("Dame tu edad: "))
if edad >= 66 and edad <= 105:
  print("Eres un adulto mayor")
elif edad >= 31 and edad <= 65:
  print("Eres un adulto")
elif edad >= 19 and edad <= 30:
  print("Eres un adulto joven")
elif edad >= 11 and edad <=18:
  print("Eres un adolescente")
elif edad >= 0 and edad <=10:
  print("Eres un niño")
else:
  print("Error, edad no valida")
# Out:
# Dame tu edad: 56
# Eres un adulto

# %%
#En este codigo quitamos los "elif" dandole el valor a todos de if, lo que provoca que todas se ejecuten y haga print a todas las que sean verdaderas, en este caso estan definidos limites con el "and"
#en este caso esta mal implementado la logica porque
#al ser if's independientes se van a evaluar cada una de ellas
#y si ponemos por ejemplo = 15 en casi todos los ifs
#se va a cumplir la condicion y no eslo que queremos
edad = int(input("Dame tu edad: "))
if edad >= 66 and edad <= 105:
  print("Eres un adulto mayor")
if edad >= 31 and edad <= 65:
  print("Eres un adulto")
if edad >= 19 and edad <= 30:
  print("Eres un adulto joven")
if edad >= 11 and edad <=18:
  print("Eres un adolescente")
if edad >= 0 and edad <=10:
  print("Eres un niño")
else:
  print("Error, edad no valida")

# %%
tabla = int(input("Ingresa la tabla: "))
x = int(input("Desde que numero debe empezar: "))
y = int(input("Hasta que numero debe llegar: "))
z = int(input("De cuanto en cuanto: "))
if tabla >= 0 and tabla <= 100:
        if x >= 0 and x <= 100:
          if y >= 0 and y <= 100:
            if z >= 0 and z <= 100:
              if x > y:
                print("Error, el primer numero debe ser mayor que el segundo")
              else:
                for i in range(x, y, z):
                  print(tabla, "*", i, "=", tabla * i)
            else:
              print("Error, el tercer numero debe estar entre 0 y 100")
          else:
            print("Error, el segundo numero debe estar entre 0 y 100")
        else:
          print("Error, el primer numero debe estar entre 0 y 100")
else:
  print("La tabla es demasiado grande, intentalo de denuevo")
# Out:
# Ingresa la tabla: 6
# Desde que numero debe empezar: 9
# Hasta que numero debe llegar: 5
# De cuanto en cuanto: 1
# Error, el primer numero debe ser mayor que el segundo

# %%
numero = int(input("Ingresa un numero : "))
while numero <= 5:
  print(numero)
  numero += 1
# Out:
# Ingresa un numero : 1
# 1
# 2
# 3
# 4
# 5

# %%
tabla = int(input("Ingresa la tabla: "))
x = int(input("Desde que numero debe empezar: "))
y = int(input("Hasta que numero debe llegar: "))
z = int(input("De cuanto en cuanto: "))
if tabla >= 0 and tabla <= 100:
        if x >= 0 and x <= 100:
          if y >= 0 and y <= 100:
            if z >= 0 and z <= 100:
              while x > y:
                print("Error, el primer numero debe ser mayor que el segundo")
                x = int(input("Desde que numero debe empezar: "))
                y = int(input("Hasta que numero debe llegar: "))
                for i in range(x, y, z):
                  print(tabla, "*", i, "=", tabla * i)
            else:
              print("Error, el tercer numero debe estar entre 0 y 100")
          else:
            print("Error, el segundo numero debe estar entre 0 y 100")
        else:
          print("Error, el primer numero debe estar entre 0 y 100")
else:
  print("La tabla es demasiado grande, intentalo de denuevo")
# Out:
#   File "<tokenize>", line 17
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#Codigo anterior, pero remplazando la mayoria de los if por while
tabla = int(input("Ingresa la tabla: "))
x = int(input("Desde que numero debe empezar: "))
y = int(input("Hasta que numero debe llegar: "))
z = int(input("De cuanto en cuanto: "))
while tabla <= 0 or tabla >= 100:
  print("La tabla es demasiado grande, intentalo de denuevo")
  tabla = int(input("Ingresa la tabla: "))
  while x <= 0 or x >= 100:
    print("Error, el primer numero debe estar entre 0 y 100")
    x = int(input("Desde que numero debe empezar: "))
    while y <= 0 or y >= 100:
      print("Error, el segundo numero debe estar entre 0 y 100")
      y = int(input("Hasta que numero debe llegar: "))
      while z <= 0 or z >= 100:
        print("Error, el tercer numero debe estar entre 0 y 100")
        z = int(input("De cuanto en cuanto: "))
        while x > y:
              print("Error, el primer numero debe ser mayor que el segundo")
              x = int(input("Desde que numero debe empezar: "))
              y = int(input("Hasta que numero debe llegar: "))
for i in range(x, y, z):
  print(tabla, "*", i, "=", tabla * i)
# Out:
# Ingresa la tabla: 5
# Desde que numero debe empezar: 1
# Hasta que numero debe llegar: 6
# De cuanto en cuanto: 3
# 5 * 1 = 5
# 5 * 4 = 20

# %% [markdown]
# # **Tema de listas**

# %%
alumnos = ["Ana", "Luis", "Carlos", "Juan"]
print(alumnos)
print(alumnos[0])
print(alumnos[3])
print(alumnos[5]) #Error de indice, el 5 no existe
# Out:
# ['Ana', 'Luis', 'Carlos', 'Juan']
# Ana
# Juan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_384/747652879.py in <cell line: 0>()
#       3 print(alumnos[0])
#       4 print(alumnos[3])
# ----> 5 print(alumnos[5]) #Error de indice, el 5 no existe
#
# IndexError: list index out of range

# %%
#Modificar un valor de la lista desde un indice especifico
alumnos[1] = "Maria Luisa"
print(alumnos)
# Out:
# ['Ana', 'Maria Luisa', 'Carlos', 'Juan', 'x', 'Carlos', 'Carlos', 'Carlos', 'Carlos', 'Carla', 'Karla']

# %%
#1 Metodo append agrega un elemento al final de la lista
alumnos.append("Karla")
print(alumnos)
# Out:
# ['Ana', 'Luis', 'Carlos', 'Juan', 'Karla']

# %%
#2 El metodo insert agrega un elemento a la lista en la posicion especificada
alumnos.insert(2, "Cristina")
print(alumnos)
# Out:
# ['Ana', 'Luis', 'Cristina', 'Carlos', 'Juan']

# %%
#3 El metodo remove, elimina un elemento especificando el valor del elemento
# debe coincidir exactamente mayusculas y minusculas
alumnos.remove("Ana")
alumnos.remove("ana") #Este marcaria error porque no esta bien escrito
print(alumnos)
# Out:
# ['Luis', 'Cristina', 'Carlos', 'Juan']

# %%
#4 pop elimina el elemento o item en la posicion especificada
alumnos.pop(2)
print(alumnos)
# Out:
# ['Ana', 'Luis', 'Juan']

# %%
#5 del tambien elimina el elemento o item en la posicion especificada
del alumnos[3]
print(alumnos)
# Out:
# ['Ana', 'Luis', 'Carlos']

# %%
# La  funcion len me permite conocer cuantos elementos tiene una lista
print("Elementos en la lista de alumnos: ", len(alumnos))
# Out:
# Elementos en la lista de alumnos:  3

# %%
alumnos.append("Ana")
alumnos.append("Ernesto")
for x in alumnos:
  print(x)
# Out:
# Ana
# Luis
# Carlos
# Ana
# Ernesto
# Ana
# Ernesto

# %%
print(alumnos)
for x in alumnos:
  print(x)
  if x == "Luis":
    break # break forza a salir del ciclo, siempre y cuando se cumpla
          # la condicion del if
# Out:
# ['Ana', 'Luis', 'Carlos', 'Ana', 'Ana', 'Ernesto']
# Ana
# Luis

# %%
software = ["Python", "Python y VS Code", "AutoCAD", "SolidWorks", "Java"]
print(software)
# Out:
# ['Python', 'Python y VS Code', 'AutoCAD', 'SolidWorks', 'Java']

# %%
if "Python" in software:
  print("Python esta en la lista de software")
else:
  print("Python no esta en la lista de software")
# Out:
# Python esta en la lista de software

# %%
# otra forma de recorrer o listar los elementos de una lista
for i in range(len(software)):
  print(software[i])

# Forma tradicional
print("")
print("Listar la lista otra vez")
print("")
for x in software:
  print(x)
# Out:
# Python
# Python y VS Code
# AutoCAD
# SolidWorks
# Java
#
# Listar la lista otra vez
#
# Python
# Python y VS Code
# AutoCAD
# SolidWorks
# Java

# %%
#Codigo de prueba
quitar_alumno = input("Ingresa el nombre del alumno a eliminar: ")
ingresar_nuevo_alumno = input("Ingresa el nombre del alumno a agregar: ")
if quitar_alumno in alumnos:
  alumnos.remove(quitar_alumno)
  alumnos.append(ingresar_nuevo_alumno)
else:
  print("Alumno no encontrado")
for x in alumnos:
  print(x)
# Out:
# Ingresa el nombre del alumno a eliminar: Luis
# Ingresa el nombre del alumno a agregar: Ana
# Carlos
# Ernesto
# Ana

# %%
#Codigo de prueba
alumnos = ["Ana", "Luis", "Carlos", "Juan"]
cantidad_alumnos = len(alumnos)
print("Estan inscritos los siguientes alumnos: ", cantidad_alumnos)
for i in range(cantidad_alumnos):
  print(alumnos[i])
# Out:
# Estan inscritos los siguientes alumnos:  4
# Los cuales son:
# Ana
# Luis
# Carlos
# Juan
